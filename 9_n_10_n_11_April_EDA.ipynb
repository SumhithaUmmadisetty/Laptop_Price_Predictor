# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#df=pd.read_csv("/content/drive/MyDrive/CGU_sem6_AIDS/datasets/laptop_price.csv")        #have to use different encoder

# %%
df=pd.read_csv("/content/drive/MyDrive/CGU_sem6_AIDS/datasets/laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.sample(5)
# Out:
#        Company            Product   TypeName  Inches       ScreenResolution  \
# 497         HP      EliteBook 840   Notebook    14.0      Full HD 1920x1080
# 20        Asus    Vivobook E200HA    Netbook    11.6               1366x768
# 52          HP             255 G6   Notebook    15.6      Full HD 1920x1080
# 457  Microsoft     Surface Laptop  Ultrabook    13.5  Touchscreen 2256x1504
# 341     Lenovo  IdeaPad 320-15ABR   Notebook    15.6      Full HD 1920x1080
#
#                              Cpu   Ram              Memory  \
# 497   Intel Core i7 7600U 2.8GHz   8GB             1TB SSD
# 20   Intel Atom x5-Z8350 1.44GHz   2GB  32GB Flash Storage
# 52     AMD A6-Series 9220 2.5GHz   4GB           256GB SSD
# 457  Intel Core M m3-7Y30 2.2GHz   4GB           128GB SSD
# 341  AMD A12-Series 9720P 3.6GHz  12GB             2TB HDD
#
#                         Gpu         OpSys   Weight  Price_euros
# 497   Intel HD Graphics 620    Windows 10   1.48kg      1749.00
# 20    Intel HD Graphics 400    Windows 10   0.98kg       191.90
# 52   AMD Radeon R4 Graphics    Windows 10   1.86kg       398.49
# 457   Intel HD Graphics 615  Windows 10 S  1.252kg       989.00
# 341          AMD Radeon 530    Windows 10    2.2kg       899.00

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(28)

# %%
df.drop_duplicates(inplace=True)

# %%
df.sample(5)
# Out:
#       Company            Product     TypeName  Inches  \
# 1136       HP           ZBook 17  Workstation    17.3
# 576   Toshiba    Tecra X40-D-10H    Ultrabook    14.0
# 364    Lenovo  IdeaPad 320-15ISK     Notebook    15.6
# 287      Asus       VivoBook S15    Ultrabook    15.6
# 493      Acer           Aspire 5     Notebook    15.6
#
#                      ScreenResolution                          Cpu   Ram  \
# 1136      IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz   8GB
# 576   Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz  16GB
# 364                          1366x768     Intel Core i3 6006U 2GHz   8GB
# 287                 Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 493                          1366x768  AMD A10-Series 9620P 2.5GHz   8GB
#
#          Memory                    Gpu       OpSys  Weight  Price_euros
# 1136  256GB SSD   Nvidia Quadro M3000M   Windows 7     3kg       3949.4
# 576   512GB SSD  Intel HD Graphics 620  Windows 10  1.24kg       1865.0
# 364   256GB SSD  Nvidia GeForce 920MX        No OS   2.2kg        499.0
# 287   256GB SSD   Nvidia GeForce 940MX  Windows 10   1.7kg        977.0
# 493     1TB HDD      AMD Radeon RX 540  Windows 10   2.2kg        579.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1275 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   Product           1275 non-null   object
#  2   TypeName          1275 non-null   object
#  3   Inches            1275 non-null   float64
#  4   ScreenResolution  1275 non-null   object
#  5   Cpu               1275 non-null   object
#  6   Ram               1275 non-null   object
#  7   Memory            1275 non-null   object
#  8   Gpu               1275 non-null   object
#  9   OpSys             1275 non-null   object
#  10  Weight            1275 non-null   object
#  11  Price_euros       1275 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 129.5+ KB

# %%
#Data Processing/ Cleaning/ EDA
#EDA: Exploratory data analysis
#univariate analysis
#bivariate analysis

# %%
df['price']=round(df['Price_euros']*95.72).astype('int')

# %%
df.sample()
# Out:
#       Company        Product            TypeName  Inches  \
# 429  Mediacom  FlexBook Edge  2 in 1 Convertible    11.6
#
#                               ScreenResolution  \
# 429  IPS Panel Full HD / Touchscreen 1920x1080
#
#                                       Cpu  Ram    Memory  \
# 429  Intel Celeron Dual Core N3350 1.1GHz  4GB  32GB SSD
#
#                        Gpu       OpSys  Weight  Price_euros  price
# 429  Intel HD Graphics 500  Windows 10  1.16kg        299.0  28620

# %%
df.drop(columns=['Price_euros'],inplace=True)

# %%
df.sample(2)
# Out:
#     Company            Product   TypeName  Inches  \
# 232  Lenovo  Legion Y720-15IKB     Gaming    15.6
# 999      HP      EliteBook 840  Ultrabook    14.0
#
#                 ScreenResolution                          Cpu   Ram  \
# 232  IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 999            Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
#
#                    Memory                      Gpu       OpSys  Weight   price
# 232  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10   3.2kg  143484
# 999             512GB SSD    Intel HD Graphics 620  Windows 10  1.48kg  199959

# %%
df['Company'].nunique() #no.of companies
# Out:
# 19

# %%
df['Company'].value_counts()  #laptops by each company
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Company'>

# %%
#removing these 4% of data, from companies which have less than 20 products since its no use of it while making a model

# %%
print(df.groupby('Company')['Company'].transform('count'))
# Out:
# 0        21
# 1        21
# 2       268
# 3        21
# 4        21
#        ...
# 1270    289
# 1271    289
# 1272    289
# 1273    268
# 1274    152
# Name: Company, Length: 1275, dtype: int64

# %%
df=df[df.groupby('Company')['Company'].transform('count')>20]

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
#resetting the index values
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1219  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1220  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1221  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1222      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1223    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1219   IPS Panel Full HD / Touchscreen 1920x1080
# 1220  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1221                                    1366x768
# 1222                                    1366x768
# 1223                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1219            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1220            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1221  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1222            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1223  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  128235
# 1           Intel HD Graphics 6000       macOS  1.34kg   86047
# 2            Intel HD Graphics 620       No OS  1.86kg   55039
# 3               AMD Radeon Pro 455       macOS  1.83kg  242885
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  172641
# ...                            ...         ...     ...     ...
# 1219         Intel HD Graphics 520  Windows 10   1.8kg   61069
# 1220         Intel HD Graphics 520  Windows 10   1.3kg  143484
# 1221             Intel HD Graphics  Windows 10   1.5kg   21920
# 1222            AMD Radeon R5 M330  Windows 10  2.19kg   73130
# 1223             Intel HD Graphics  Windows 10   2.2kg   35321
#
# [1224 rows x 12 columns]

# %%
df['Company'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Company'>

# %%
sorted_order_comp=df.groupby('Company')['price'].mean().sort_values(ascending=False)
sorted_order_comp
# Out:
# Company
# MSI        165491.055556
# Apple      149725.190476
# Toshiba    121355.000000
# Dell       114789.773196
# Asus       107572.947368
# Lenovo     104704.397924
# HP         103407.656716
# Acer        60635.198020
# Name: price, dtype: float64

# %%
sorted_order_comp.index
# Out:
# Index(['MSI', 'Apple', 'Toshiba', 'Dell', 'Asus', 'Lenovo', 'HP', 'Acer'], dtype='object', name='Company')

# %%
sns.barplot(x=df['Company'],y=df['price'],order=sorted_order_comp.index) #the black lines indicate the difference the cheapest and costliest laptop (range) longer line->larger difference
# Out:
# <Axes: xlabel='Company', ylabel='price'>

# %%
sns.barplot(x=df['Company'],y=df['price'],order=sorted_order_comp.index, errorbar=None)
# Out:
# <Axes: xlabel='Company', ylabel='price'>

# %%
print(df['Product'].value_counts())
# Out:
# Product
# XPS 13                30
# Inspiron 3567         25
# 250 G6                21
# Vostro 3568           19
# Legion Y520-15IKBN    19
#                       ..
# Portege X30-D-10L      1
# Zenbook UX390UA        1
# Portege X30-D-10J      1
# Latitude E5470         1
# VivoBook E12           1
# Name: count, Length: 589, dtype: int64

# %%
#if the number of categories is more than 20, we will render that column non-meaningful for our analysis

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# <ipython-input-33-4bcf6fa0a033>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
df.sample( )
# Out:
#     Company TypeName  Inches   ScreenResolution                          Cpu  \
# 164    Dell   Gaming    15.6  Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#      Ram                Memory                      Gpu       OpSys  Weight  \
# 164  8GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10  2.56kg
#
#       price
# 164  101510

# %%
#TypeName

# %%
  df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='TypeName'>

# %%
sorted_order_type=df.groupby('TypeName')['price'].mean().sort_values(ascending=False)
sorted_order_type
# Out:
# TypeName
# Workstation           218275.931034
# Gaming                160014.125000
# Ultrabook             148385.766082
# 2 in 1 Convertible    124385.157895
# Notebook               76183.475291
# Netbook                66215.636364
# Name: price, dtype: float64

# %%
sorted_order_type.index
# Out:
# Index(['Workstation', 'Gaming', 'Ultrabook', '2 in 1 Convertible', 'Notebook',
#        'Netbook'],
#       dtype='object', name='TypeName')

# %%
sns.barplot(x=df['TypeName'],y=df['price'],order=sorted_order_type.index,ci=None,palette='Blues',hue=df['TypeName'])
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-40-cf0423d94777>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['TypeName'],y=df['price'],order=sorted_order_type.index,ci=None,palette='Blues',hue=df['TypeName'])

# %%
palette=sns.color_palette('Blues',len(sorted_order_type))[: : -1]
color_dict=dict(zip(sorted_order_type.index,palette))

# %%
sns.barplot(x=df['TypeName'],y=df['price'],order=sorted_order_type.index,errorbar=None,palette=color_dict,hue=df['TypeName'])
plt.xticks(rotation=45)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
sns.displot(df['Inches'],kde=True)

# %%
sns.barplot(x=df['Inches'],y=df['price'])
# Out:
# <Axes: xlabel='Inches', ylabel='price'>

# %%
print(df['ScreenResolution'].value_counts())
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# 1920x1080                                          2
# IPS Panel Quad HD+ 3200x1800                       2
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
a="IPS Panel Retina Display 2880x1800"
a.split()
# Out:
# ['IPS', 'Panel', 'Retina', 'Display', '2880x1800']

# %%
a.split()[-1]
# Out:
# '2880x1800'

# %%
a.split()[-1].split('x')
# Out:
# ['2880', '1800']

# %%
a.split()[-1].split('x')[0]
# Out:
# '2880'

# %%
lambda a:a.split()[-1].split('x')[0].astype(int)
# Out:
# <function __main__.<lambda>(a)>

# %%
a.split()[0]
# Out:
# 'IPS'

# %%
df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')
# Out:
# <ipython-input-53-40f364c1e3d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
# <ipython-input-53-40f364c1e3d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')

# %%
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if 'IPS' in a else 0)
# Out:
# <ipython-input-54-3a8df247edfe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS']=df['ScreenResolution'].apply(lambda a:1 if 'IPS' in a else 0)

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if 'Touchscreen' in a else 0)
# Out:
# <ipython-input-55-e68d8852748c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if 'Touchscreen' in a else 0)

# %%
df.sample(3)
# Out:
#     Company  TypeName  Inches             ScreenResolution  \
# 281    Acer  Notebook    15.6                     1366x768
# 383    Acer  Notebook    15.6           IPS Panel 1366x768
# 505    Dell  Notebook    17.3  IPS Panel Full HD 1920x1080
#
#                                       Cpu   Ram                Memory  \
# 281  Intel Celeron Dual Core 3205U 1.5GHz   2GB              16GB SSD
# 383            Intel Core i5 8250U 1.6GHz  12GB               1TB HDD
# 505            Intel Core i5 8250U 1.6GHz   8GB  128GB SSD +  1TB HDD
#
#                       Gpu       OpSys  Weight  price  X_res  Y_res  IPS  \
# 281     Intel HD Graphics   Chrome OS  2.19kg  19048   1366    768    0
# 383  Nvidia GeForce MX130  Windows 10   2.2kg  66429   1366    768    1
# 505        AMD Radeon 530       Linux   2.8kg  85095   1920   1080    1
#
#      Touchscreen
# 281            0
# 383            0
# 505            0

# %%
df['Clock Speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace("GHz","")).astype('float')
# Out:
# <ipython-input-57-94f5d93571e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clock Speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace("GHz","")).astype('float')

# %%
df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# Out:
# <ipython-input-58-aa3ac16de377>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df['Cpu']
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1219         Intel Core i7
# 1220         Intel Core i7
# 1221    Intel Celeron Dual
# 1222         Intel Core i7
# 1223    Intel Celeron Dual
# Name: Cpu, Length: 1224, dtype: object

# %%
def fetch_processor_name(text):
    if 'Core' in text:
        return text
    elif text.split()[0]=='Intel':
        return " ".join(text.split()[0:2])
    elif text.split()[0]=='AMD':
        if text[4]=="A":
            return "AMD A Series"
        elif text[4]=="E":
            return "AMD E Series"
        elif text[4]=="R":
            return "AMD Ryezn Series"
        elif text[4]=="F":
            return "AMD FX Series"
    else:
        return "Others"

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor_name)
# Out:
# <ipython-input-61-8c092dd80c87>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(fetch_processor_name)

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i7       493
# Intel Core i5       411
# Intel Core i3       134
# Intel Celeron        71
# AMD A Series         45
# Intel Pentium        30
# Intel Core M         16
# AMD E Series          9
# Intel Atom            5
# AMD Ryezn Series      4
# Intel Xeon            4
# AMD FX Series         2
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Cpu'>

# %%
sorted_order_cpu=df.groupby('Cpu')['price'].mean().sort_values(ascending=False)

# %%
palette=sns.color_palette('Blues',len(sorted_order_cpu))[: : -1]
color_dict2=dict(zip(sorted_order_cpu.index,palette))

# %%
sns.barplot(x=df['Cpu'],y=df['price'],order=sorted_order_cpu.index,errorbar=None,palette=color_dict2,hue=df['Cpu'])
plt.xticks(rotation=90)
plt.show()

# %%
print(df['Ram'].value_counts())
# Out:
# Ram
# 8GB     595
# 4GB     351
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
print(df['Weight'].value_counts())
# Out:
# Weight
# 2.2kg      115
# 2.1kg       58
# 2.4kg       42
# 2.5kg       37
# 2.3kg       36
#           ...
# 2.21kg       1
# 2.191kg      1
# 1.08kg       1
# 2.34kg       1
# 4.0kg        1
# Name: count, Length: 175, dtype: int64

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')
df['Ram']
# Out:
# <ipython-input-69-7b7d356f30d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1219     4
# 1220    16
# 1221     2
# 1222     6
# 1223     4
# Name: Ram, Length: 1224, dtype: int64

# %%
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')
# Out:
# <ipython-input-70-d0238b158d02>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
df['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1219    1.80
# 1220    1.30
# 1221    1.50
# 1222    2.19
# 1223    2.20
# Name: Weight, Length: 1224, dtype: float64

# %%
df.sample()
# Out:
#     Company  TypeName  Inches   ScreenResolution            Cpu  Ram   Memory  \
# 869    Acer  Notebook    15.6  Full HD 1920x1080  Intel Core i3    4  1TB HDD
#
#                        Gpu       OpSys  Weight  price  X_res  Y_res  IPS  \
# 869  Intel HD Graphics 620  Windows 10     2.4  47764   1920   1080    0
#
#      Touchscreen  Clock Speed
# 869            0          2.4

# %%
df['Ram'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Ram'>

# %%
sorted_order_ram=df.groupby('Ram')['price'].mean().sort_values(ascending=False)

# %%
palette=sns.color_palette('Blues',len(sorted_order_ram))[: : -1]
color_dict3=dict(zip(sorted_order_ram.index,palette))

# %%
sns.barplot(x=df['Ram'],y=df['price'],order=sorted_order_ram.index,errorbar=None,palette=color_dict3,hue=df['Ram'])
plt.xticks(rotation=90)
plt.show()

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    885
# 1    339
# Name: count, dtype: int64

# %%
df['IPS'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['price'])
# Out:
# <Axes: xlabel='IPS', ylabel='price'>

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1224 non-null   object
#  1   TypeName          1224 non-null   object
#  2   Inches            1224 non-null   float64
#  3   ScreenResolution  1224 non-null   object
#  4   Cpu               1224 non-null   object
#  5   Ram               1224 non-null   int64
#  6   Memory            1224 non-null   object
#  7   Gpu               1224 non-null   object
#  8   OpSys             1224 non-null   object
#  9   Weight            1224 non-null   float64
#  10  price             1224 non-null   int64
#  11  X_res             1224 non-null   int64
#  12  Y_res             1224 non-null   int64
#  13  IPS               1224 non-null   int64
#  14  Touchscreen       1224 non-null   int64
#  15  Clock Speed       1224 non-null   float64
# dtypes: float64(3), int64(6), object(7)
# memory usage: 153.1+ KB

# %%
sns.displot(df['Clock Speed'],kde=True)

# %%
sns.scatterplot(x=df['Clock Speed'],y=df['price'],hue=df['TypeName'])
# Out:
# <Axes: xlabel='Clock Speed', ylabel='price'>

# %%
sns.scatterplot(x=df['Clock Speed'],y=df['price'],hue=df['Company'])
# Out:
# <Axes: xlabel='Clock Speed', ylabel='price'>

# %%
sns.scatterplot(x=df['Clock Speed'],y=df['price'],hue=df['Cpu'])
plt.legend(loc='upper right',bbox_to_anchor=(1.5,1))

# %%
sns.displot(df['Weight'],kde=True)

# %%
sns.scatterplot(x=df['Weight'],y=df['price'],hue=df['TypeName'])
# Out:
# <Axes: xlabel='Weight', ylabel='price'>

# %%
df_g=df[df['TypeName']=='Gaming']

# %%
sns.scatterplot(x=df_g['Weight'],y=df['price'])
# Out:
# <Axes: xlabel='Weight', ylabel='price'>

# %%
sns.scatterplot(x=df['Weight'],y=df['price'],hue=df['Inches'])
# Out:
# <Axes: xlabel='Weight', ylabel='price'>

# %%
import plotly.express as px

# %%
fig=px.scatter(x=df['Weight'],y=df['price'],color=df['TypeName'])

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ea13b8e-cd39-4456-ada1-100dfe9a85f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ea13b8e-cd39-4456-ada1-100dfe9a85f1")) {                    Plotly.newPlot(                        "5ea13b8e-cd39-4456-ada1-100dfe9a85f1",                        [{"hovertemplate":"color=Ultrabook\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ultrabook","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Ultrabook","showlegend":true,"x":[1.37,1.34,1.83,1.37,2.04,1.34,1.3,1.6,1.83,0.92,1.37,1.83,1.22,1.91,1.35,1.88,1.2,1.35,1.37,1.7,1.8,1.4,1.88,0.92,1.83,1.21,1.25,1.38,1.3,1.5,1.23,1.21,1.6,1.25,0.97,1.48,1.23,1.12,1.21,1.2,1.4,1.6,1.2,1.37,1.41,1.37,1.7,1.63,1.21,1.7,1.26,1.9,1.2,1.88,1.9,1.36,1.1,1.13,1.91,1.13,1.1,1.2,1.36,1.7,1.43,1.75,1.6,1.32,1.36,1.4,1.42,1.36,0.91,1.05,1.3,1.34,1.29,1.32,1.2,1.34,1.16,1.21,1.24,1.4,1.84,1.1,1.23,1.14,1.8,1.36,1.2,1.1,1.36,1.17,1.32,1.7,1.18,1.2,1.26,1.47,1.7,0.92,1.29,1.32,1.25,1.13,1.13,1.1,1.54,1.45,1.54,1.96,1.29,1.2,1.6,1.32,1.13,1.09,1.84,1.39,1.36,1.26,1.36,1.36,1.36,1.7,1.3,1.36,1.1,1.5,1.11,1.48,1.43,1.26,1.54,1.2,1.26,1.29,1.26,1.47,1.2,1.29,0.92,1.26,1.3,0.99,1.3,1.4,1.5,1.5,1.5,1.16,1.23,1.05,1.26,1.84,1.88,1.26,1.4,1.7,1.54,1.23,0.92,1.2,0.92,1.26,1.29,1.08,1.54,1.45,1.2],"xaxis":"x","y":[128235,86047,242885,172641,204838,110911,143101,73704,233554,120837,145356,273568,93710,63079,105196,124245,178901,95529,135827,84138,189813,91413,104924,144537,66908,157842,100410,107111,114194,120799,131998,155928,84616,105196,192780,103569,133912,94667,186558,138698,89200,109982,130466,195269,90838,187506,93518,140517,239204,100496,127786,100410,151142,153914,63462,167510,167405,218433,47764,251265,179284,167223,160810,185984,143580,116336,105196,228005,136784,177848,176302,172105,186654,267920,105196,126638,86052,133912,133912,109599,188090,153056,178518,160140,132955,181868,178901,234514,87967,151620,138784,108642,179666,161445,143484,104909,177943,108068,119076,168850,220060,111514,143484,177943,104335,239204,179475,200916,178996,98209,140517,182155,214413,104813,161767,172200,196130,296732,124148,109982,157938,151142,156885,140919,169903,142526,121373,168467,171339,187896,129126,199959,138698,147313,180644,152195,149227,155449,129126,165117,215753,139560,124436,114768,164015,133912,196130,78332,108657,111702,135262,188473,131998,213073,181389,71981,207877,219864,220060,143484,79543,105196,111322,256530,122426,164004,141378,91795,210411,122522,69780],"yaxis":"y","type":"scattergl"},{"hovertemplate":"color=Notebook\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Notebook","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Notebook","showlegend":true,"x":[1.86,2.1,1.86,1.86,2.2,2.2,2.2,1.86,2.3,2.2,2.5,1.65,2.71,1.44,2.1,2.8,1.86,2.1,2.0,2.3,2.2,2.2,2.3,2.8,2.2,1.86,1.49,2.4,2.13,1.91,2.0,2.0,2.8,1.7,1.4,1.86,1.86,1.44,1.9,2.2,2.1,2.2,2.02,2.2,2.5,1.63,2.2,2.1,1.96,2.2,1.49,2.2,2.2,2.0,1.91,2.1,2.2,1.58,1.85,1.58,1.63,1.63,2.16,2.0,1.7,2.1,2.2,2.5,2.1,1.86,1.63,1.65,2.8,2.5,2.36,2.2,2.2,2.05,1.63,1.9,2.2,1.32,3.0,1.75,2.1,1.86,2.0,2.1,1.9,1.91,2.1,2.03,3.0,2.13,2.1,2.1,3.0,1.49,2.71,2.2,2.0,2.5,2.3,2.1,1.9,2.02,2.0,2.77,2.06,2.8,2.8,2.5,1.49,2.5,2.1,2.23,2.3,2.2,2.4,2.1,2.2,2.8,1.63,2.2,2.1,2.2,2.3,2.0,2.69,1.9,2.37,2.1,1.6,2.36,2.1,2.2,2.2,2.1,2.69,2.2,2.04,1.49,1.68,3.0,1.91,2.9,2.8,2.2,2.1,2.18,2.24,2.2,2.5,2.05,2.14,2.2,2.3,2.8,2.2,2.8,2.8,2.8,2.25,2.2,3.0,2.15,1.95,2.2,2.19,2.54,2.0,2.05,2.5,2.4,1.3,2.8,2.2,2.2,2.2,2.3,1.86,1.1,2.23,2.33,1.45,1.95,1.4,1.48,2.79,2.0,2.1,2.2,1.44,2.23,2.06,2.0,2.0,1.85,1.48,1.84,2.0,2.0,2.2,2.2,2.1,1.44,2.06,1.84,2.4,2. ...

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# AMD Radeon R5 M315           1
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:" ".join(x.split()[0:2]))
# Out:
# <ipython-input-97-2666f22119d7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD          586
# Nvidia GeForce    353
# AMD Radeon        166
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# Nvidia GTX          1
# AMD R4              1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
def gpu_name(text):
    if text=='Intel Graphics':
        return "Intel HD"
    elif text=='AMD R17M-M1-70' or text=='AMD R4':
        return "AMD Radeon"
    elif text=='Nvidia GTX':
        return "Nvidia GeForce"
    else:
        return text

# %%
df['Gpu']=df['Gpu'].apply(gpu_name)
# Out:
# <ipython-input-100-301c410e1d23>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD          587
# Nvidia GeForce    354
# AMD Radeon        168
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Gpu'>

# %%
sorted_order_gpu=df.groupby('Gpu')['price'].mean().sort_values(ascending=False)
print(sorted_order_gpu)
# Out:
# Gpu
# Nvidia Quadro     235328.483871
# Intel Iris        165480.090909
# AMD FirePro       156712.800000
# Nvidia GeForce    131904.392655
# Intel UHD         115416.044118
# Intel HD           94231.223169
# AMD Radeon         71443.297619
# Name: price, dtype: float64

# %%
palette=sns.color_palette('Blues',len(sorted_order_gpu))[: : -1]
color_dist4=dict(zip(sorted_order_gpu.index,palette))

# %%
sns.barplot(x=df['Gpu'],y=df['price'],order=sorted_order_gpu.index,errorbar=None,palette=color_dist4,hue=df['Gpu'])
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Windows 10 S       2
# Android            2
# Name: count, dtype: int64

# %%
def fetch_os_name(text):
    if text=="Windows 10 S":
        return "Windows 10"
    elif text=="Mac OS X" or text=="macOS":
        return "Mac OS"
    elif text=="Chrome OS" or text=="Linux" or text=="Android":
        return "Linux/Others"
    else:
        return text

# %%
df['OpSys']=df['OpSys'].apply(fetch_os_name)
# Out:
# <ipython-input-108-21b8552f1324>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['OpSys'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='OpSys'>

# %%
sorted_order_os=df.groupby('OpSys')['price'].mean().sort_values(ascending=False)
print(sorted_order_os)


palette=sns.color_palette('Blues',len(sorted_order_os))[: : -1]
color_dist5=dict(zip(sorted_order_os.index,palette))

sns.barplot(x=df['OpSys'],y=df['price'],order=sorted_order_os.index,errorbar=None,palette=color_dist5,hue=df['OpSys'])
plt.xticks(rotation=90)
plt.show()
# Out:
# OpSys
# Windows 7       161446.177778
# Mac OS          149725.190476
# Windows 10      112125.036525
# Linux/Others     53605.597561
# No OS            53492.825397
# Name: price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
# Out:
# <ipython-input-111-5a8c076be408>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#MEMORY COLUMN

# %%
# HDD
# SDD
# Flash storage
# hybrid

# %%
df['Memory'].astype('str').replace("\.0","",regex=True)
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1219              128GB SSD
# 1220              512GB SSD
# 1221     64GB Flash Storage
# 1222                1TB HDD
# 1223              500GB HDD
# Name: Memory, Length: 1224, dtype: object

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 64GB Flash Storage                10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 512GB SSD +  512GB SSD             1
# 64GB SSD                           1
# 64GB Flash Storage +  1TB HDD      1
# 512GB SSD +  256GB SSD             1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory']=df['Memory'].str.replace("GB","")
df['Memory']=df['Memory'].str.replace("TB","000")
# Out:
# <ipython-input-116-8ed97e19a654>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-116-8ed97e19a654>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        214
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 256 SSD +  2000 HDD              10
# 64 Flash Storage                 10
# 256 Flash Storage                 8
# 1.0000 Hybrid                     7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 16 SSD                            3
# 512 SSD +  2000 HDD               3
# 32 SSD                            2
# 256 SSD +  256 SSD                2
# 1000 SSD +  1000 HDD              2
# 512 Flash Storage                 2
# 256 SSD +  500 HDD                2
# 128 SSD +  2000 HDD               2
# 512 SSD +  512 SSD                1
# 64 SSD                            1
# 64 Flash Storage +  1000 HDD      1
# 512 SSD +  256 SSD                1
# 1000 HDD +  1000 HDD              1
# 128 HDD                           1
# 240 SSD                           1
# 8 SSD                             1
# 508 Hybrid                        1
# 1.0000 HDD                        1
# 512 SSD +  1.0000 Hybrid          1
# 256 SSD +  1.0000 Hybrid          1
# Name: count, dtype: int64

# %%
new=df['Memory'].str.split('+',expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]
# Out:
# <ipython-input-118-880982f97623>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-118-880982f97623>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-118-880982f97623>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['layer1hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['layer1flash']=df['first'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-119-5508168c3858>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-119-5508168c3858>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-119-5508168c3858>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-119-5508168c3858>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample()
# Out:
#      Company  TypeName  Inches            Cpu  Ram   Memory       Gpu  \
# 1186    Dell  Notebook    15.6  Intel Core i5    4  500 HDD  Intel HD
#
#           OpSys  Weight  price  ...  Y_res  IPS  Touchscreen  Clock Speed  \
# 1186  Windows 7    2.24  70546  ...    768    0            0          2.3
#
#         first second layer1HDD  layer1SSD  layer1hybrid  layer1flash
# 1186  500 HDD   None         1          0             0            0
#
# [1 rows x 21 columns]

# %%
df['first']=df['first'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-121-043ccd27c636>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['second'].fillna("0",inplace=True)
df['second']=df['second'].str.strip()
# Out:
# <ipython-input-122-35a0e6b0e560>:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# <ipython-input-122-35a0e6b0e560>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-122-35a0e6b0e560>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['layer2hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['layer2flash']=df['second'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-123-162a55623722>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-123-162a55623722>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-123-162a55623722>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-123-162a55623722>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['second']=df['second'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-124-7e4a144e1deb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample(4)
# Out:
#      Company  TypeName  Inches            Cpu  Ram               Memory  \
# 326       HP  Notebook    14.0  Intel Core i5    8              256 SSD
# 1116    Dell    Gaming    15.6  Intel Core i7    8  128 SSD +  1000 HDD
# 381     Asus    Gaming    17.3  Intel Core i7    8             1000 HDD
# 189       HP  Notebook    13.3  Intel Core i5    8              512 SSD
#
#                  Gpu       OpSys  Weight   price  ...  first  second  \
# 326         Intel HD  Windows 10    1.48  121373  ...    256       0
# 1116  Nvidia GeForce  Windows 10    2.62  143389  ...    128    1000
# 381   Nvidia GeForce  Windows 10    3.00   99453  ...   1000       0
# 189        Intel UHD  Windows 10    1.49   91795  ...    512       0
#
#       layer1HDD  layer1SSD  layer1hybrid layer1flash layer2HDD  layer2SSD  \
# 326           0          1             0           0         0          0
# 1116          0          1             0           0         1          0
# 381           1          0             0           0         0          0
# 189           0          1             0           0         0          0
#
#       layer2hybrid  layer2flash
# 326              0            0
# 1116             0            0
# 381              0            0
# 189              0            0
#
# [4 rows x 25 columns]

# %%
df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')
# Out:
# <ipython-input-126-985d4fe1ffcd>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-126-985d4fe1ffcd>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1224 non-null   object
#  1   TypeName      1224 non-null   object
#  2   Inches        1224 non-null   float64
#  3   Cpu           1224 non-null   object
#  4   Ram           1224 non-null   int64
#  5   Memory        1224 non-null   object
#  6   Gpu           1224 non-null   object
#  7   OpSys         1224 non-null   object
#  8   Weight        1224 non-null   float64
#  9   price         1224 non-null   int64
#  10  X_res         1224 non-null   int64
#  11  Y_res         1224 non-null   int64
#  12  IPS           1224 non-null   int64
#  13  Touchscreen   1224 non-null   int64
#  14  Clock Speed   1224 non-null   float64
#  15  first         1224 non-null   int64
#  16  second        1224 non-null   int64
#  17  layer1HDD     1224 non-null   int64
#  18  layer1SSD     1224 non-null   int64
#  19  layer1hybrid  1224 non-null   int64
#  20  layer1flash   1224 non-null   int64
#  21  layer2HDD     1224 non-null   int64
#  22  layer2SSD     1224 non-null   int64
#  23  layer2hybrid  1224 non-null   int64
#  24  layer2flash   1224 non-null   int64
# dtypes: float64(3), int64(16), object(6)
# memory usage: 239.2+ KB

# %%
df['HDD']=df['first']*df['layer1HDD']+df['second']*df['layer2HDD']
df['SSD']=df['first']*df['layer1SSD']+df['second']*df['layer2SSD']
df['Hybrid']=df['first']*df['layer1hybrid']+df['second']*df['layer2hybrid']
df['Flash Storage']=df['first']*df['layer1flash']+df['second']*df['layer2flash']
# Out:
# <ipython-input-128-56ebca5dfa20>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-128-56ebca5dfa20>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-128-56ebca5dfa20>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-128-56ebca5dfa20>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample()
# Out:
#     Company            TypeName  Inches            Cpu  Ram   Memory  \
# 365    Dell  2 in 1 Convertible    13.3  Intel Core i7    8  256 SSD
#
#            Gpu       OpSys  Weight  price  ...  layer1hybrid  layer1flash  \
# 365  Intel UHD  Windows 10    1.62  83182  ...             0            0
#
#      layer2HDD  layer2SSD  layer2hybrid  layer2flash  HDD  SSD  Hybrid  \
# 365          0          0             0            0    0  256       0
#
#      Flash Storage
# 365              0
#
# [1 rows x 29 columns]

# %%
df.drop(columns=['first','second','layer1HDD','layer1SSD','layer1hybrid','layer1flash','layer2HDD','layer2SSD','layer2hybrid','layer2flash'],inplace=True)
# Out:
# <ipython-input-130-44dcf0ebcf36>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample()
# Out:
#      Company TypeName  Inches            Cpu  Ram               Memory  \
# 1136    Asus   Gaming    15.6  Intel Core i7    8  256 SSD +  1000 HDD
#
#                  Gpu       OpSys  Weight  price  X_res  Y_res  IPS  \
# 1136  Nvidia GeForce  Windows 10   2.591  87009   1920   1080    1
#
#       Touchscreen  Clock Speed   HDD  SSD  Hybrid  Flash Storage
# 1136            0          2.6  1000  256       0              0

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# <ipython-input-132-8cab1fd6fcc0>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram       Gpu         OpSys  \
# 904    Acer  Notebook    14.0  Intel Celeron    4  Intel HD  Linux/Others
#
#      Weight  price  X_res  Y_res  IPS  Touchscreen  Clock Speed  HDD  SSD  \
# 904    1.68  33406   1366    768    0            0          1.6    0    0
#
#      Hybrid  Flash Storage
# 904       0             32

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     price     X_res     Y_res  \
# Inches         1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram            0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight         0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# price          0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# X_res         -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# Y_res         -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# IPS           -0.104090  0.223322  0.038753  0.289225  0.283969  0.294360
# Touchscreen   -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# Clock Speed    0.296510  0.356482  0.313267  0.422535  0.187056  0.178539
# HDD            0.484807  0.093039  0.463869 -0.091752 -0.104049 -0.110182
# SSD           -0.114322  0.589636 -0.063144  0.654751  0.523882  0.518090
# Hybrid         0.054984  0.057335  0.108974  0.026676  0.004609  0.003717
# Flash Storage -0.230659 -0.047725 -0.178962 -0.023384 -0.013602  0.020131
#
#                     IPS  Touchscreen  Clock Speed       HDD       SSD  \
# Inches        -0.104090    -0.359497     0.296510  0.484807 -0.114322
# Ram            0.223322     0.094037     0.356482  0.093039  0.589636
# Weight         0.038753    -0.291506     0.313267  0.463869 -0.063144
# price          0.289225     0.161443     0.422535 -0.091752  0.654751
# X_res          0.283969     0.320954     0.187056 -0.104049  0.523882
# Y_res          0.294360     0.317174     0.178539 -0.110182  0.518090
# IPS            1.000000     0.154500     0.085098 -0.085151  0.228186
# Touchscreen    0.154500     1.000000    -0.105203 -0.178165  0.240469
# Clock Speed    0.085098    -0.105203     1.000000  0.101844  0.248993
# HDD           -0.085151    -0.178165     0.101844  1.000000 -0.373613
# SSD            0.228186     0.240469     0.248993 -0.373613  1.000000
# Hybrid        -0.010827    -0.034638     0.050055 -0.064209 -0.046574
# Flash Storage  0.074771    -0.012073    -0.214263 -0.101384 -0.140474
#
#                  Hybrid  Flash Storage
# Inches         0.054984      -0.230659
# Ram            0.057335      -0.047725
# Weight         0.108974      -0.178962
# price          0.026676      -0.023384
# X_res          0.004609      -0.013602
# Y_res          0.003717       0.020131
# IPS           -0.010827       0.074771
# Touchscreen   -0.034638      -0.012073
# Clock Speed    0.050055      -0.214263
# HDD           -0.064209      -0.101384
# SSD           -0.046574      -0.140474
# Hybrid         1.000000      -0.012162
# Flash Storage -0.012162       1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='winter')
# Out:
# <Axes: >

# %%
print(df.corr(numeric_only=True)['price'])
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# price            1.000000
# X_res            0.553707
# Y_res            0.552964
# IPS              0.289225
# Touchscreen      0.161443
# Clock Speed      0.422535
# HDD             -0.091752
# SSD              0.654751
# Hybrid           0.026676
# Flash Storage   -0.023384
# Name: price, dtype: float64

# %%
df['ppi']=round((df['X_res']**2+df['Y_res']**2)**0.5/df['Inches']).astype(int)
# Out:
# <ipython-input-137-919600591f76>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)
# Out:
# <ipython-input-138-3e9aaf9787dd>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop(columns=['Flash Storage','Hybrid'],inplace=True)
# Out:
# <ipython-input-139-76a4c132f290>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample()
# Out:
#    Company  TypeName            Cpu  Ram             Gpu       OpSys  Weight  \
# 76    Acer  Notebook  Intel Core i3    4  Nvidia GeForce  Windows 10     2.2
#
#     price  IPS  Touchscreen  Clock Speed   HDD  SSD  ppi
# 76  50732    0            0          2.7  1000    0  141

# %%
df['SSD'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='SSD'>

# %%
sns.barplot(x=df['SSD'],y=df['price'],errorbar=None)
# Out:
# <Axes: xlabel='SSD', ylabel='price'>

# %%
sns.displot(df['ppi'],kde=True)

# %%
sns.scatterplot(x=df['ppi'],y=df['price'])
# Out:
# <Axes: xlabel='ppi', ylabel='price'>

# %%
sns.kdeplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
print(df['price'].describe())
# Out:
# count      1224.000000
# mean     107645.160131
# std       64118.113675
# min       16655.000000
# 25%       58666.750000
# 50%       93710.000000
# 75%      141426.000000
# max      468932.000000
# Name: price, dtype: float64

# %%
df.to_csv('laptop_data_cleaned.csv',index=False)

# %%
x=df.drop(columns=['price'])
y=df['price']

# %%
x
# Out:
#      Company            TypeName            Cpu  Ram         Gpu       OpSys  \
# 0      Apple           Ultrabook  Intel Core i5    8  Intel Iris      Mac OS
# 1      Apple           Ultrabook  Intel Core i5    8    Intel HD      Mac OS
# 2         HP            Notebook  Intel Core i5    8    Intel HD       No OS
# 3      Apple           Ultrabook  Intel Core i7   16  AMD Radeon      Mac OS
# 4      Apple           Ultrabook  Intel Core i5    8  Intel Iris      Mac OS
# ...      ...                 ...            ...  ...         ...         ...
# 1219  Lenovo  2 in 1 Convertible  Intel Core i7    4    Intel HD  Windows 10
# 1220  Lenovo  2 in 1 Convertible  Intel Core i7   16    Intel HD  Windows 10
# 1221  Lenovo            Notebook  Intel Celeron    2    Intel HD  Windows 10
# 1222      HP            Notebook  Intel Core i7    6  AMD Radeon  Windows 10
# 1223    Asus            Notebook  Intel Celeron    4    Intel HD  Windows 10
#
#       Weight  IPS  Touchscreen  Clock Speed   HDD  SSD  ppi
# 0       1.37    1            0          2.3     0  128  227
# 1       1.34    0            0          1.8     0    0  128
# 2       1.86    0            0          2.5     0  256  141
# 3       1.83    1            0          2.7     0  512  221
# 4       1.37    1            0          3.1     0  256  227
# ...      ...  ...          ...          ...   ...  ...  ...
# 1219    1.80    1            1          2.5     0  128  157
# 1220    1.30    1            1          2.5     0  512  276
# 1221    1.50    0            0          1.6     0    0  112
# 1222    2.19    0            0          2.5  1000    0  100
# 1223    2.20    0            0          1.6   500    0  100
#
# [1224 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=32)

# %%
x_train.shape,x_test.shape
# Out:
# ((1040, 13), (184, 13))

# %%
x_train
# Out:
#      Company            TypeName            Cpu  Ram             Gpu  \
# 460   Lenovo            Notebook  Intel Core i5    8        Intel HD
# 1161    Asus            Notebook  Intel Core i7   16  Nvidia GeForce
# 1192    Dell  2 in 1 Convertible  Intel Core i7   16  Nvidia GeForce
# 330     Dell            Notebook  Intel Core i5    8  Nvidia GeForce
# 1220  Lenovo  2 in 1 Convertible  Intel Core i7   16        Intel HD
# ...      ...                 ...            ...  ...             ...
# 1095      HP  2 in 1 Convertible  Intel Core i7    8        Intel HD
# 252   Lenovo            Notebook  Intel Core i3    4        Intel HD
# 88      Asus              Gaming  AMD FX Series    8      AMD Radeon
# 892      MSI              Gaming  Intel Core i7    8  Nvidia GeForce
# 727     Acer            Notebook  Intel Core i5    4        Intel HD
#
#            OpSys  Weight  IPS  Touchscreen  Clock Speed   HDD  SSD  ppi
# 460   Windows 10    1.70    0            0          2.5     0  180  157
# 1161  Windows 10    2.20    0            0          2.8  1000  128  141
# 1192  Windows 10    2.77    0            1          2.7     0  512  127
# 330   Windows 10    2.00    0            0          1.6     0  256  141
# 1220  Windows 10    1.30    1            1          2.5     0  512  276
# ...          ...     ...  ...          ...          ...   ...  ...  ...
# 1095  Windows 10    1.48    0            1          2.6     0  256  221
# 252        No OS    2.20    0            0          2.0     0  256  141
# 88    Windows 10    2.45    0            0          3.0  1000    0  141
# 892   Windows 10    2.20    0            0          2.8  1000  128  141
# 727   Windows 10    2.10    0            0          2.5     0  256  100
#
# [1040 rows x 13 columns]

# %%
y_train
# Out:
# 460     130562
# 1161    167414
# 1192    172200
# 330     109384
# 1220    143484
#          ...
# 1095    172200
# 252      42500
# 88       66908
# 892     114768
# 727      57336
# Name: price, Length: 1040, dtype: int64

# %%
x_train.dtypes
# Out:
# Company         object
# TypeName        object
# Cpu             object
# Ram              int64
# Gpu             object
# OpSys           object
# Weight         float64
# IPS              int64
# Touchscreen      int64
# Clock Speed    float64
# HDD              int64
# SSD              int64
# ppi              int64
# dtype: object

# %%
df.sample()
# Out:
#     Company  TypeName            Cpu  Ram       Gpu       OpSys  Weight  \
# 572  Lenovo  Notebook  Intel Core i5    8  Intel HD  Windows 10     1.7
#
#       price  IPS  Touchscreen  Clock Speed  HDD  SSD  ppi
# 572  141091    1            0          2.5    0  256  157

# %% [markdown]
# #ENCODING
# label encoding is for output columns
#
# one hot encoding - Nominal data : names type
#
# ordinal encoding - it is used for ordered data . like high low  grades , ranks

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression,Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor

# %%
#step 1= OneHot encoding within column transformer
#step 2= linear regression
#step1+step2= pipeline

# %%
x_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram             Gpu       OpSys  Weight  \
# 312  Lenovo  Notebook  Intel Core i5    4  Nvidia GeForce  Windows 10    2.79
#
#      IPS  Touchscreen  Clock Speed   HDD  SSD  ppi
# 312    0            0          2.5  1000    0  106

# %%
#Linear Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.8063654329079217
# RMSE:  25827.142779670954
# MAE: 19379.00705313919

# %%
#Regularization
# '''
# 1.L2 Regularization( Ridge Regression)
#       . Penalize large coefficients
#       . The model still uses all the features , but keep their weights small
#       . Generally works when they are many small / medium useful features
# 2.L1 Regularization (Lasso Regression)
#       .it can actually set some coefficients to zero , if the feature is not herlping enough
#       . Higher Alpha reduces large coefficients.

# %%
#Ridge Regression (L2 regularization)
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=Ridge()
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.8065179687316562
# RMSE:  25816.968096729564
# MAE: 19395.415380397208

# %%
#Lasso Regression (L1 regularization)
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=Lasso()
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.8063975888277016
# RMSE:  25824.99819870652
# MAE: 19375.09546328814

# %%
#KNN
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=KNeighborsRegressor(n_neighbors=4)
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.687348220024937
# RMSE:  32818.246428379316
# MAE: 22068.375

# %%
#SVR
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=SVR(C=10000000000)
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.7356290497407745
# RMSE:  30178.092475734094
# MAE: 18850.176631598944

# %%
#Decision Tree Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=DecisionTreeRegressor()
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.7588730727659685
# RMSE:  28820.91568461624
# MAE: 19880.855072463768

# %%
#AdaBoost
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=AdaBoostRegressor(n_estimators=5)
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.7305646081314725
# RMSE:  30465.77568267037
# MAE: 25412.793473586196

# %%
#RandomForest
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=RandomForestRegressor()
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.856339886659245
# RMSE:  22246.05575524391
# MAE: 16212.368803959625

# %%
#XGBRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=XGBRegressor()
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.8472908139228821
# RMSE:  22935.98828125
# MAE: 16611.650390625

# %%
#Gradient Booster
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=GradientBoostingRegressor()
pipe=Pipeline([('step 1',step1),('step 2',step2)])
pipe.fit(x_train,y_train)
y_pred=pipe.predict(x_test)
print("R2 Score:",r2_score(y_test,y_pred))
print("RMSE: ",root_mean_squared_error(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score: 0.8625994370500302
# RMSE:  21756.006256633922
# MAE: 16251.906099090604

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))

# %%
# Streamlit

# %%
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 44.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.8 MB/s eta 0:00:00

# %%
# %%writefile abc.txt
# This is my text file
# I am adding another line of text here.
# And another as well
# Out:
# Writing abc.txt

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import pickle
lr_model=pickle.load(open('pipe.pkl','rb'))
df=pickle.load(open('df.pkl','rb'))

st.title("Laptop Price Predictor App")
st.write("This app is created using the data taken from kaggle website.")
st.write("The prediction here is based on the data available, hence might not align perfectly with the real-life data.")

company=st.selectbox("Laptop Manufacturer",df['Company'].unique(),index=4)
typename=st.selectbox("Type of Laptop",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
cpu_speed=st.slider("CPU Clock Speed",min_value=0.8,max_value=4.0,step=0.1,value=2.5)
ram=st.radio("Amount of RAM on the system",[4,6,8,12,16,24,32,64,128],index=2,horizontal=True)
gpu=st.selectbox("Graphics Card on the system",df['Gpu'].unique(),index=1)
os=st.selectbox("Operating System",df['OpSys'].unique(),index=2)
weight=st.slider("Weight of the laptop(in kg)",min_value=0.6,max_value=5.0,step=0.2,value=2.0)
ips=st.selectbox("Does the laptop display have IPS Panel?",["Yes",'No'],index=1)
touchscreen=st.selectbox("Does the laptop have a touchscreen?",["Yes",'No'],index=1)
ssd=st.selectbox("What is the SSD storage on the system? If system has HDD storage only, select 0",
                 [0,128,256,512,1024],index=3)
hdd=st.selectbox("What is the HDD storage on the system? If system has SSD only, then select 0",
                 [0,128,256,512,1024,2048],index=0)
screen_size=st.slider("Screen size(in inches, measured diagonally)",min_value=10.0,max_value=18.5,step=0.1,value=15.6)
screen_resolution=st.selectbox("Screen Resolution(in horizontal x vertical pixels)",
                               ["2560x1600","1440x900","1920x1080","2880x1800","1366x768","2304x1440",
                                "3200x1800","1920x1200","2256x1504","3840x2160","2160x1440","2560x1440",
                                "1600x900","2736x1824","2400x1600"],index=2)

if st.button("PREDICT PRICE"):
    X_res=int(screen_resolution.split('x')[0])
    Y_res=int(screen_resolution.split('x')[1])
    ppi=(X_res**2+Y_res**2)**0.5/screen_size
    if ips=='Yes':
        ips=1
    else:
        ips=0
    if touchscreen=='Yes':
        touchscreen=1
    else:
        touchscreen=0
    query=np.array([[company,typename,cpu,ram,gpu,os,weight,ips,touchscreen,cpu_speed,hdd,ssd,ppi]])
    op=lr_model.predict(query)
    #st.header(op)
    st.subheader("The predicted price of the laptop with the above mentioned specification is ₹"+ str(int(round(op[0],-2))))
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹⠸⠼
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.169.103.203:8501
#
# ⠴⠦⠧your url is: https://dull-bars-punch.loca.lt
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
#   Stopping...
# ^C
